# %%
import os

path = './data/ml_dogcat/train/'
os.listdir(path)
# Out:
# ['dog.1487.jpg',
#  'cat.2123.jpg',
#  'cat.8962.jpg',
#  'dog.10071.jpg',
#  'cat.8142.jpg',
#  'dog.11016.jpg',
#  'cat.10007.jpg',
#  'dog.3361.jpg',
#  'cat.11585.jpg',
#  'dog.4690.jpg',
#  'cat.10087.jpg',
#  'dog.3781.jpg',
#  'dog.1315.jpg',
#  'cat.9351.jpg',
#  'dog.1159.jpg',
#  'cat.1857.jpg',
#  'dog.8546.jpg',
#  'cat.3369.jpg',
#  'dog.4351.jpg',
#  'dog.11807.jpg',
#  'cat.10097.jpg',
#  'cat.3384.jpg',
#  'cat.11740.jpg',
#  'cat.4955.jpg',
#  'cat.4393.jpg',
#  'dog.10742.jpg',
#  'cat.3607.jpg',
#  'dog.3983.jpg',
#  'cat.2956.jpg',
#  'cat.3867.jpg',
#  'cat.7630.jpg',
#  'cat.12411.jpg',
#  'dog.11152.jpg',
#  'dog.5339.jpg',
#  'dog.10797.jpg',
#  'dog.1903.jpg',
#  'dog.10668.jpg',
#  'dog.2005.jpg',
#  'dog.3898.jpg',
#  'cat.10517.jpg',
#  'cat.9798.jpg',
#  'dog.8667.jpg',
#  'cat.8746.jpg',
#  'cat.1834.jpg',
#  'cat.297.jpg',
#  'cat.5809.jpg',
#  'cat.6362.jpg',
#  'dog.3562.jpg',
#  'cat.363.jpg',
#  'cat.8458.jpg',
#  'dog.2699.jpg',
#  'cat.8358.jpg',
#  'dog.3415.jpg',
#  'dog.11964.jpg',
#  'cat.6180.jpg',
#  'cat.3401.jpg',
#  'cat.1903.jpg',
#  'cat.8940.jpg',
#  'cat.11147.jpg',
#  'cat.8880.jpg',
#  'cat.4810.jpg',
#  'cat.5671.jpg',
#  'cat.3282.jpg',
#  'cat.3411.jpg',
#  'dog.8071.jpg',
#  'cat.12127.jpg',
#  'dog.6569.jpg',
#  'dog.9134.jpg',
#  'dog.8931.jpg',
#  'dog.12036.jpg',
#  'dog.4797.jpg',
#  'dog.1146.jpg',
#  'dog.7500.jpg',
#  'dog.9981.jpg',
#  'cat.3663.jpg',
#  'cat.11999.jpg',
#  'cat.6144.jpg',
#  'cat.10228.jpg',
#  'dog.10164.jpg',
#  'dog.4304.jpg',
#  'dog.11148.jpg',
#  'dog.11548.jpg',
#  'dog.761.jpg',
#  'dog.4517.jpg',
#  'dog.12204.jpg',
#  'cat.2225.jpg',
#  'dog.10576.jpg',
#  'dog.8257.jpg',
#  'cat.9387.jpg',
#  'cat.1712.jpg',
#  'cat.1391.jpg',
#  'dog.6866.jpg',
#  'dog.5292.jpg',
#  'cat.543.jpg',
#  'cat.7247.jpg',
#  'cat.8975.jpg',
#  'dog.7526.jpg',
#  'cat.11686.jpg',
#  'dog.11474.jpg',
#  'cat.5647.jpg',
#  'dog.7481.jpg',
#  'cat.2714.jpg',
#  'cat.2504.jpg',
#  'cat.10306.jpg',
#  'cat.11765.jpg',
#  'dog.734.jpg',
#  'dog.11749.jpg',
#  'cat.4880.jpg',
#  'dog.12078.jpg',
#  'dog.9504.jpg',
#  'cat.10241.jpg',
#  'dog.6559.jpg',
#  'dog.1282.jpg',
#  'cat.639.jpg',
#  'dog.10395.jpg',
#  'cat.6496.jpg',
#  'cat.4706.jpg',
#  'dog.11333.jpg',
#  'cat.3372.jpg',
#  'dog.5186.jpg',
#  'dog.8122.jpg',
#  'dog.371.jpg',
#  'cat.4162.jpg',
#  'dog.10528.jpg',
#  'dog.1857.jpg',
#  'cat.8442.jpg',
#  'dog.2373.jpg',
#  'cat.1325.jpg',
#  'dog.1100.jpg',
#  'dog.11415.jpg',
#  'cat.5802.jpg',
#  'dog.5950.jpg',
#  'dog.12008.jpg',
#  'cat.11648.jpg',
#  'cat.1683.jpg',
#  'dog.3293.jpg',
#  'cat.11469.jpg',
#  'cat.11992.jpg',
#  'cat.2505.jpg',
#  'cat.11498.jpg',
#  'cat.4385.jpg',
#  'cat.10133.jpg',
#  'dog.6832.jpg',
#  'cat.8836.jpg',
#  'cat.4006.jpg',
#  'cat.5052.jpg',
#  'dog.5727.jpg',
#  'cat.10695.jpg',
#  'dog.9131.jpg',
#  'cat.3598.jpg',
#  'dog.6518.jpg',
#  'cat.9703.jpg',
#  'cat.9281.jpg',
#  'cat.5845.jpg',
#  'dog.10651.jpg',
#  'dog.6686.jpg',
#  'dog.11997.jpg',
#  'dog.3075.jpg',
#  'cat.931.jpg',
#  'cat.9066.jpg',
#  'dog.3006.jpg',
#  'cat.11828.jpg',
#  'cat.11411.jpg',
#  'dog.2642.jpg',
#  'cat.3037.jpg',
#  'cat.3393.jpg',
#  'cat.8123.jpg',
#  'dog.3328.jpg',
#  'cat.1080.jpg',
#  'cat.508.jpg',
#  'dog.9439.jpg',
#  'dog.10111.jpg',
#  'cat.7050.jpg',
#  'cat.5476.jpg',
#  'cat.12439.jpg',
#  'dog.807.jpg',
#  'cat.1010.jpg',
#  'cat.10030.jpg',
#  'dog.6846.jpg',
#  'dog.7879.jpg',
#  'dog.6279.jpg',
#  'cat.7468.jpg',
#  'cat.8859.jpg',
#  'cat.1438.jpg',
#  'dog.12142.jpg',
#  'dog.9785.jpg',
#  'dog.3083.jpg',
#  'cat.2571.jpg',
#  'dog.4307.jpg',
#  'dog.5085.jpg',
#  'cat.2618.jpg',
#  'dog.4773.jpg',
#  'cat.2347.jpg',
#  'dog.11754.jpg',
#  'dog.5716.jpg',
#  'cat.7343.jpg',
#  'dog.6758.jpg',
#  'cat.11558.jpg',
#  'dog.2193.jpg',
#  'cat.9116.jpg',
#  'cat.4783.jpg',
#  'dog.7398.jpg',
#  'dog.11626.jpg',
#  'dog.10565.jpg',
#  'dog.5549.jpg',
#  'dog.9616.jpg',
#  'cat.11564.jpg',
#  'dog.8265.jpg',
#  'cat.3880.jpg',
#  'cat.10278.jpg',
#  'dog.4491.jpg',
#  'dog.11326.jpg',
#  'dog.10261.jpg',
#  'cat.2525.jpg',
#  'dog.3097.jpg',
#  'dog.295.jpg',
#  'dog.6355.jpg',
#  'cat.2485.jpg',
#  'cat.6673.jpg',
#  'dog.4262.jpg',
#  'cat.1900.jpg',
#  'dog.4051.jpg',
#  'dog.9455.jpg',
#  'dog.10341.jpg',
#  'dog.3936.jpg',
#  'dog.11439.jpg',
#  'dog.10356.jpg',
#  'dog.11945.jpg',
#  'dog.10583.jpg',
#  'dog.9148.jpg',
#  'cat.5785.jpg',
#  'cat.10310.jpg',
#  'cat.11689.jpg',
#  'dog.9472.jpg',
#  'dog.9752.jpg',
#  'dog.5693.jpg',
#  'dog.5587.jpg',
#  'cat.4894.jpg',
#  'cat.5866.jpg',
#  'dog.6654.jpg',
#  'cat.7088.jpg',
#  'dog.6345.jpg',
#  'dog.6631.jpg',
#  'cat.10144.jpg',
#  'dog.8872.jpg',
#  'cat.10440.jpg',
#  'dog.2371.jpg',
#  'dog.7682.jpg',
#  'dog.3178.jpg',
#  'cat.9585.jpg',
#  'dog.4814.jpg',
#  'cat.11581.jpg',
#  'cat.11194.jpg',
#  'cat.11544.jpg',
#  'cat.11680.jpg',
#  'dog.11577.jpg',
#  'cat.5844.jpg',
#  'cat.940.jpg',
#  'cat.9800.jpg',
#  'cat.8349.jpg',
#  'cat.3652.jpg',
#  'cat.9827.jpg',
#  'dog.3859.jpg',
#  'dog.10752.jpg',
#  'dog.10432.jpg',
#  'dog.11070.jpg',
#  'dog.8894.jpg',
#  'dog.224.jpg',
#  'cat.3110.jpg',
#  'dog.4354.jpg',
#  'dog.5707.jpg',
#  'cat.11553.jpg',
#  'cat.4406.jpg',
#  'cat.4127.jpg',
#  'dog.2510.jpg',
#  'dog.3683.jpg',
#  'dog.4837.jpg',
#  'cat.6083.jpg',
#  'dog.1216.jpg',
#  'dog.7441.jpg',
#  'cat.400.jpg',
#  'dog.7866.jpg',
#  'dog.9667.jpg',
#  'cat.18.jpg',
#  'dog.7609.jpg',
#  'dog.5962.jpg',
#  'cat.1409.jpg',
#  'dog.12182.jpg',
#  'dog.6313.jpg',
#  'dog.2578.jpg',
#  'cat.9765.jpg',
#  'cat.4513.jpg',
#  'cat.752.jpg',
#  'dog.5916.jpg',
#  'dog.2437.jpg',
#  'cat.2977.jpg',
#  'cat.1748.jpg',
#  'cat.9724.jpg',
#  'cat.132.jpg',
#  'cat.6028.jpg',
#  'dog.10136.jpg',
#  'cat.11338.jpg',
#  'dog.1617.jpg',
#  'cat.11892.jpg',
#  'dog.1626.jpg',
#  'cat.11529.jpg',
#  'dog.10332.jpg',
#  'cat.1805.jpg',
#  'cat.3807.jpg',
#  'cat.10285.jpg',
#  'cat.11866.jpg',
#  'dog.11973.jpg',
#  'dog.2293.jpg',
#  'cat.11186.jpg',
#  'dog.983.jpg',
#  'dog.7762.jpg',
#  'cat.8892.jpg',
#  'dog.5149.jpg',
#  'cat.6956.jpg',
#  'dog.8390.jpg',
#  'dog.3706.jpg',
#  'cat.11461.jpg',
#  'dog.3789.jpg',
#  'dog.2758.jpg',
#  'dog.128.jpg',
#  'dog.4394.jpg',
#  'dog.9714.jpg',
#  'dog.6549.jpg',
#  'dog.2774.jpg',
#  'cat.10259.jpg',
#  'cat.6050.jpg',
#  'cat.8503.jpg',
#  'cat.10365.jpg',
#  'dog.12077.jpg',
#  'cat.7667.jpg',
#  'cat.2846.jpg',
#  'cat.5333.jpg',
#  'cat.9261.jpg',
#  'cat.1928.jpg',
#  'dog.10896.jpg',
#  'cat.2378.jpg',
#  'cat.8915.jpg',
#  'cat.1337.jpg',
#  'dog.1862.jpg',
#  'cat.2811.jpg',
#  'cat.2098.jpg',
#  'cat.9049.jpg',
#  'dog.10051.jpg',
#  'dog.1096.jpg',
#  'dog.6870.jpg',
#  'cat.12450.jpg',
#  'cat.8565.jpg',
#  'cat.9670.jpg',
#  'dog.11102.jpg',
#  'cat.10534.jpg',
#  'dog.8052.jpg',
#  'cat.8700.jpg',
#  'cat.3783.jpg',
#  'dog.870.jpg',
#  'dog.2780.jpg',
#  'dog.5182.jpg',
#  'cat.1828.jpg',
#  'cat.2674.jpg',
#  'dog.5517.jpg',
#  'dog.10748.jpg',
#  'dog.4574.jpg',
#  'dog.367.jpg',
#  'dog.10483.jpg',
#  'cat.10783.jpg',
#  'cat.1579.jpg',
#  'cat.5490.jpg',
#  'dog.4997.jpg',
#  'dog.879.jpg',
#  'cat.9957.jpg',
#  'cat.553.jpg',
#  'dog.9175.jpg',
#  'cat.8211.jpg',
#  'cat.3530.jpg',
#  'dog.8331.jpg',
#  'cat.12066.jpg',
#  'cat.9018.jpg',
#  'cat.11792.jpg',
#  'dog.3907.jpg',
#  'cat.3742.jpg',
#  'cat.619.jpg',
#  'dog.4508.jpg',
#  'cat.8465.jpg',
#  'dog.2809.jpg',
#  'cat.7429.jpg',
#  'dog.6929.jpg',
#  'cat.8537.jpg',
#  'dog.3847.jpg',
#  'dog.7692.jpg',
#  'dog.6623.jpg',
#  'cat.6053.jpg',
#  'dog.9164.jpg',
#  'cat.427.jpg',
#  'dog.5557.jpg',
#  'cat.10671.jpg',
#  'dog.3041.jpg',
#  'cat.1385.jpg',
#  'cat.11953.jpg',
#  'dog.4833.jpg',
#  'cat.6991.jpg',
#  'dog.7307.jpg',
#  'dog.8304.jpg',
#  'dog.11729.jpg',
#  'dog.733.jpg',
#  'dog.4149.jpg',
#  'cat.11874.jpg',
#  'cat.11784.jpg',
#  'dog.5865.jpg',
#  'cat.3034.jpg',
#  'cat.11045.jpg',
#  'dog.10982.jpg',
#  'cat.11390.jpg',
#  'cat.7658.jpg',
#  'dog.2882.jpg',
#  'cat.3933.jpg',
#  'dog.3512.jpg',
#  'cat.848.jpg',
#  'cat.6829.jpg',
#  'cat.1536.jpg',
#  'cat.8436.jpg',
#  'cat.3560.jpg',
#  'cat.3715.jpg',
#  'dog.4909.jpg',
#  'cat.3647.jpg',
#  'dog.10802.jpg',
#  'dog.4739.jpg',
#  'dog.2349.jpg',
#  'dog.8024.jpg',
#  'dog.2477.jpg',
#  'dog.11936.jpg',
#  'dog.4938.jpg',
#  'cat.1108.jpg',
#  'cat.4248.jpg',
#  'dog.7855.jpg',
#  'cat.11948.jpg',
#  'dog.11811.jpg',
#  'dog.6950.jpg',
#  'cat.8665.jpg',
#  'dog.5955.jpg',
#  'cat.10752.jpg',
#  'dog.6715.jpg',
#  'dog.12308.jpg',
#  'dog.9649.jpg',
#  'cat.3640.jpg',
#  'cat.2552.jpg',
#  'cat.6190.jpg',
#  'dog.9600.jpg',
#  'dog.9992.jpg',
#  'cat.6987.jpg',
#  'dog.6007.jpg',
#  'cat.8163.jpg',
#  'cat.12378.jpg',
#  'dog.11848.jpg',
#  'dog.4426.jpg',
#  'dog.12312.jpg',
#  'cat.9695.jpg',
#  'dog.10709.jpg',
#  'cat.1931.jpg',
#  'cat.4870.jpg',
#  'dog.4408.jpg',
#  'dog.649.jpg',
#  'cat.1645.jpg',
#  'cat.11815.jpg',
#  'cat.9035.jpg',
#  'dog.6767.jpg',
#  'dog.4188.jpg',
#  'dog.1114.jpg',
#  'cat.1558.jpg',
#  'dog.11705.jpg',
#  'cat.206.jpg',
#  'dog.12199.jpg',
#  'cat.4296.jpg',
#  'cat.8269.jpg',
#  'cat.1613.jpg',
#  'cat.1794.jpg',
#  'cat.2740.jpg',
#  'cat.1605.jpg',
#  'cat.3319.jpg',
#  'cat.7202.jpg',
#  'cat.6265.jpg',
#  'cat.3478.jpg',
#  'cat.6350.jpg',
#  'cat.33.jpg',
#  'dog.2960.jpg',
#  'dog.1502.jpg',
#  'cat.8938.jpg',
#  'dog.1811.jpg',
#  'cat.709.jpg',
#  'dog.7820.jpg',
#  'cat.1206.jpg',
#  'cat.131.jpg',
#  'cat.4381.jpg',
#  'cat.3328.jpg',
#  'dog.12051.jpg',
#  'dog.720.jpg',
#  'cat.11785.jpg',
#  'cat.2863.jpg',
#  'dog.11732.jpg',
#  'cat.2672.jpg',
#  'dog.441.jpg',
#  'cat.9388.jpg',
#  'dog.4349.jpg',
#  'dog.1692.jpg',
#  'dog.11066.jpg',
#  'dog.12045.jpg',
#  'dog.9037.jpg',
#  'cat.5111.jpg',
#  'cat.2082.jpg',
#  'dog.10814.jpg',
#  'cat.2482.jpg',
#  'cat.9238.jpg',
#  'cat.3694.jpg',
#  'cat.8093.jpg',
#  'dog.5386.jpg',
#  'cat.8071.jpg',
#  'dog.8424.jpg',
#  'cat.8099.jpg',
#  'dog.3516.jpg',
#  'cat.5644.jpg',
#  'cat.9590.jpg',
#  'dog.709.jpg',
#  'dog.12222.jpg',
#  'dog.772.jpg',
#  'cat.2389.jpg',
#  'dog.5616.jpg',
#  'cat.36.jpg',
#  'dog.4271.jpg',
#  'cat.6375.jpg',
#  'cat.3218.jpg',
#  'dog.6976.jpg',
#  'dog.3300.jpg',
#  'cat.5816.jpg',
#  'cat.5296.jpg',
#  'dog.10177.jpg',
#  'dog.4974.jpg',
#  'dog.8905.jpg',
#  'dog.10912.jpg',
#  'cat.11957.jpg',
#  'cat.6822.jpg',
#  'dog.5943.jpg',
#  'cat.3896.jpg',
#  'cat.7436.jpg',
#  'dog.6824.jpg',
#  'cat.4773.jpg',
#  'dog.10040.jpg',
#  'dog.3113.jpg',
#  'cat.1606.jpg',
#  'dog.11835.jpg',
#  'dog.11890.jpg',
#  'dog.5060.jpg',
#  'dog.752.jpg',
#  'cat.2951.jpg',
#  'cat.3267.jpg',
#  'dog.87.jpg',
#  'cat.8004.jpg',
#  'dog.1245.jpg',
#  'dog.6780.jpg',
#  'cat.12053.jpg',
#  'cat.12491.jpg',
#  'cat.2111.jpg',
#  'cat.8664.jpg',
#  'dog.764.jpg',
#  'cat.10436.jpg',
#  'dog.4343.jpg',
#  'cat.6521.jpg',
#  'dog.10272.jpg',
#  'cat.4187.jpg',
#  'cat.3506.jpg',
#  'dog.9586.jpg',
#  'dog.3393.jpg',
#  'dog.2457.jpg',
#  'dog.7337.jpg',
#  'cat.10344.jpg',
#  'dog.10555.jpg',
#  'cat.760.jpg',
#  'cat.5600.jpg',
#  'dog.4525.jpg',
#  'cat.4390.jpg',
#  'dog.1147.jpg',
#  'cat.7765.jpg',
#  'cat.4476.jpg',
#  'dog.6259.jpg',
#  'dog.1291.jpg',
#  'dog.9045.jpg',
#  'dog.9646.jpg',
#  'dog.4151.jpg',
#  'dog.10302.jpg',
#  'cat.2102.jpg',
#  'cat.488.jpg',
#  'cat.2934.jpg',
#  'cat.10617.jpg',
#  'dog.9875.jpg',
#  'dog.3951.jpg',
#  'dog.1719.jpg',
#  'cat.5011.jpg',
#  'dog.7169.jpg',
#  'cat.4925.jpg',
#  'dog.10856.jpg',
#  'cat.6101.jpg',
#  'cat.3118.jpg',
#  'dog.7066.jpg',
#  'cat.5765.jpg',
#  'cat.11703.jpg',
#  'cat.8339.jpg',
#  'dog.5839.jpg',
#  'dog.12163.jpg',
#  'dog.1537.jpg',
#  'dog.9608.jpg',
#  'dog.7523.jpg',
#  'cat.5070.jpg',
#  'cat.3741.jpg',
#  'dog.2548.jpg',
#  'cat.10897.jpg',
#  'dog.8300.jpg',
#  'dog.6578.jpg',
#  'cat.2978.jpg',
#  'cat.4727.jpg',
#  'dog.2647.jpg',
#  'dog.10556.jpg',
#  'cat.8333.jpg',
#  'dog.1512.jpg',
#  'cat.12342.jpg',
#  'dog.1043.jpg',
#  'cat.2673.jpg',
#  'cat.6918.jpg',
#  'cat.1943.jpg',
#  'cat.10537.jpg',
#  'dog.4964.jpg',
#  'dog.5778.jpg',
#  'cat.8738.jpg',
#  'cat.1176.jpg',
#  'dog.1235.jpg',
#  'cat.933.jpg',
#  'dog.11904.jpg',
#  'dog.12482.jpg',
#  'cat.9384.jpg',
#  'cat.389.jpg',
#  'dog.7247.jpg',
#  'dog.7901.jpg',
#  'dog.458.jpg',
#  'dog.6277.jpg',
#  'cat.12409.jpg',
#  'cat.11653.jpg',
#  'cat.11282.jpg',
#  'dog.10041.jpg',
#  'dog.6085.jpg',
#  'dog.10124.jpg',
#  'dog.3336.jpg',
#  'dog.12173.jpg',
#  'cat.9720.jpg',
#  'cat.8138.jpg',
#  'dog.10688.jpg',
#  'dog.5582.jpg',
#  'cat.8213.jpg',
#  'dog.2336.jpg',
#  'dog.5123.jpg',
#  'dog.8698.jpg',
#  'dog.12272.jpg',
#  'cat.11651.jpg',
#  'cat.11487.jpg',
#  'cat.11345.jpg',
#  'cat.10662.jpg',
#  'cat.11010.jpg',
#  'dog.1992.jpg',
#  'cat.5247.jpg',
#  'dog.2141.jpg',
#  'cat.8251.jpg',
#  'dog.7869.jpg',
#  'dog.4152.jpg',
#  'dog.9706.jpg',
#  'dog.896.jpg',
#  'dog.9233.jpg',
#  'cat.3676.jpg',
#  'cat.1817.jpg',
#  'dog.11337.jpg',
#  'dog.11525.jpg',
#  'cat.3758.jpg',
#  'dog.8160.jpg',
#  'cat.12163.jpg',
#  'dog.386.jpg',
#  'dog.7535.jpg',
#  'cat.3215.jpg',
#  'dog.2920.jpg',
#  'dog.1729.jpg',
#  'cat.9502.jpg',
#  'cat.5720.jpg',
#  'dog.6222.jpg',
#  'dog.9236.jpg',
#  'dog.8613.jpg',
#  'dog.10788.jpg',
#  'dog.2253.jpg',
#  'cat.9615.jpg',
#  'cat.7959.jpg',
#  'cat.4045.jpg',
#  'dog.12060.jpg',
#  'dog.1772.jpg',
#  'dog.901.jpg',
#  'dog.3307.jpg',
#  'dog.5772.jpg',
#  'dog.2657.jpg',
#  'cat.9028.jpg',
#  'cat.6774.jpg',
#  'cat.1358.jpg',
#  'dog.5514.jpg',
#  'cat.6756.jpg',
#  'dog.8326.jpg',
#  'cat.4374.jpg',
#  'dog.1338.jpg',
#  'dog.5469.jpg',
#  'cat.11123.jpg',
#  'dog.11077.jpg',
#  'dog.7564.jpg',
#  'cat.8048.jpg',
#  'dog.4629.jpg',
#  'dog.3690.jpg',
#  'cat.4227.jpg',
#  'cat.7944.jpg',
#  'dog.9915.jpg',
#  'dog.9256.jpg',
#  'cat.4165.jpg',
#  'cat.5173.jpg',
#  'cat.5459.jpg',
#  'cat.4661.jpg',
#  'dog.106.jpg',
#  'cat.10912.jpg',
#  'cat.7948.jpg',
#  'cat.87.jpg',
#  'cat.1864.jpg',
#  'dog.6194.jpg',
#  'dog.10706.jpg',
#  'cat.11841.jpg',
#  'dog.6424.jpg',
#  'dog.8192.jpg',
#  'cat.4865.jpg',
#  'cat.3669.jpg',
#  'dog.10088.jpg',
#  'dog.9679.jpg',
#  'dog.7173.jpg',
#  'cat.11023.jpg',
#  'cat.9353.jpg',
#  'cat.11600.jpg',
#  'dog.8318.jpg',
#  'cat.6322.jpg',
#  'dog.7397.jpg',
#  'dog.2145.jpg',
#  'cat.4371.jpg',
#  'dog.6264.jpg',
#  'dog.2545.jpg',
#  'dog.4778.jpg',
#  'cat.7063.jpg',
#  'cat.3777.jpg',
#  'cat.3773.jpg',
#  'dog.10615.jpg',
#  'cat.5596.jpg',
#  'dog.4628.jpg',
#  'dog.4901.jpg',
#  'cat.12430.jpg',
#  'dog.7912.jpg',
#  'cat.7346.jpg',
#  'dog.11786.jpg',
#  'dog.6073.jpg',
#  'dog.10887.jpg',
#  'cat.2100.jpg',
#  'cat.6556.jpg',
#  'dog.9172.jpg',
#  'dog.4661.jpg',
#  'cat.10941.jpg',
#  'cat.5829.jpg',
#  'cat.1549.jpg',
#  'cat.1624.jpg',
#  'dog.6274.jpg',
#  'cat.3589.jpg',
#  'cat.2137.jpg',
#  'dog.5384.jpg',
#  'cat.4892.jpg',
#  'dog.834.jpg',
#  'cat.10776.jpg',
#  'dog.12344.jpg',
#  'dog.558.jpg',
#  'cat.9994.jpg',
#  'cat.2060.jpg',
#  'dog.12210.jpg',
#  'cat.12154.jpg',
#  'dog.4681.jpg',
#  'cat.5724.jpg',
#  'dog.10058.jpg',
#  'dog.5460.jpg',
#  'dog.96.jpg',
#  'dog.11454.jpg',
#  'dog.5987.jpg',
#  'dog.9968.jpg',
#  'cat.764.jpg',
#  'cat.12444.jpg',
#  'dog.1426.jpg',
#  'dog.1174.jpg',
#  'cat.11462.jpg',
#  'cat.5884.jpg',
#  'dog.1856.jpg',
#  'cat.9829.jpg',
#  'cat.3277.jpg',
#  'dog.5726.jpg',
#  'cat.4074.jpg',
#  'cat.4593.jpg',
#  'cat.1420.jpg',
#  'dog.5512.jpg',
#  'cat.5202.jpg',
#  'cat.4525.jpg',
#  'cat.11857.jpg',
#  'dog.5007.jpg',
#  'cat.11749.jpg',
#  'cat.4379.jpg',
#  'dog.1127.jpg',
#  'dog.1694.jpg',
#  'dog.212.jpg',
#  'cat.3375.jpg',
#  'dog.7000.jpg',
#  'cat.10757.jpg',
#  'cat.10731.jpg',
#  'dog.7929.jpg',
#  'cat.2991.jpg',
#  'dog.7853.jpg',
#  'cat.4597.jpg',
#  'dog.9892.jpg',
#  'dog.302.jpg',
#  'cat.9396.jpg',
#  'cat.10180.jpg',
#  'dog.11765.jpg',
#  'dog.11680.jpg',
#  'cat.11277.jpg',
#  'cat.2835.jpg',
#  'dog.1002.jpg',
#  'cat.7241.jpg',
#  'cat.2717.jpg',
#  'cat.3409.jpg',
#  'cat.473.jpg',
#  'dog.7161.jpg',
#  'cat.5903.jpg',
#  'dog.1459.jpg',
#  'dog.8831.jpg',
#  'cat.1484.jpg',
#  'cat.7860.jpg',
#  'cat.1313.jpg',
#  'cat.4140.jpg',
#  'dog.9965.jpg',
#  'dog.8164.jpg',
#  'dog.6452.jpg',
#  'cat.8218.jpg',
#  'dog.9340.jpg',
#  'cat.1062.jpg',
#  'dog.11785.jpg',
#  'dog.8794.jpg',
#  'dog.103.jpg',
#  'dog.11159.jpg',
#  'dog.9944.jpg',
#  'cat.10768.jpg',
#  'cat.9109.jpg',
#  'cat.9601.jpg',
#  'dog.12268.jpg',
#  'cat.8223.jpg',
#  'dog.7065.jpg',
#  'dog.531.jpg',
#  'cat.9223.jpg',
#  'cat.6390.jpg',
#  'dog.4745.jpg',
#  'dog.8682.jpg',
#  'dog.12408.jpg',
#  'dog.7092.jpg',
#  'dog.3558.jpg',
#  'dog.2961.jpg',
#  'dog.4298.jpg',
#  'cat.11369.jpg',
#  'cat.9583.jpg',
#  'cat.12043.jpg',
#  'cat.5629.jpg',
#  'cat.3076.jpg',
#  'dog.2438.jpg',
#  'dog.5485.jpg',
#  'dog.8317.jpg',
#  'dog.11162.jpg',
#  'dog.290.jpg',
#  'dog.5648.jpg',
#  'cat.7380.jpg',
#  'cat.8874.jpg',
#  'dog.6301.jpg',
#  'dog.3489.jpg',
#  'dog.7145.jpg',
#  'cat.5781.jpg',
#  'dog.3687.jpg',
#  'cat.8682.jpg',
#  'dog.3882.jpg',
#  'cat.10803.jpg',
#  'cat.3695.jpg',
#  'cat.7206.jpg',
#  'cat.2750.jpg',
#  'dog.2606.jpg',
#  'dog.2240.jpg',
#  'dog.12185.jpg',
#  'cat.7142.jpg',
#  'dog.7405.jpg',
#  'dog.3776.jpg',
#  'cat.6075.jpg',
#  'dog.11872.jpg',
#  'cat.3930.jpg',
#  'dog.3881.jpg',
#  'cat.6172.jpg',
#  'dog.10605.jpg',
#  'cat.2094.jpg',
#  'dog.7908.jpg',
#  'cat.9156.jpg',
#  'dog.11431.jpg',
#  'dog.3050.jpg',
#  'dog.6825.jpg',
#  'cat.7400.jpg',
#  'dog.10184.jpg',
#  'dog.3634.jpg',
#  'dog.5899.jpg',
#  'dog.4869.jpg',
#  'dog.11041.jpg',
#  'cat.10336.jpg',
#  'cat.5071.jpg',
#  'cat.7048.jpg',
#  'cat.9333.jpg',
#  'dog.2617.jpg',
#  'dog.12463.jpg',
#  'cat.5981.jpg',
#  'dog.8645.jpg',
#  'cat.2599.jpg',
#  'cat.9506.jpg',
#  'cat.2752.jpg',
#  'cat.1832.jpg',
#  'dog.5937.jpg',
#  'dog.121.jpg',
#  'dog.6850.jpg',
#  'dog.405.jpg',
#  'dog.7403.jpg',
#  'cat.8633.jpg',
#  'cat.1042.jpg',
#  'dog.6015.jpg',
#  'cat.9875.jpg',
#  'cat.9745.jpg',
#  'cat.11273.jpg',
#  'cat.865.jpg',
#  'cat.7710.jpg',
#  'cat.3415.jpg',
#  'cat.9319.jpg',
#  'dog.6992.jpg',
#  'cat.7028.jpg',
#  'dog.2254.jpg',
#  'dog.12119.jpg',
#  'dog.7516.jpg',
#  'cat.6584.jpg',
#  'cat.10974.jpg',
#  'dog.9546.jpg',
#  'cat.12370.jpg',
#  'cat.10549.jpg',
#  'dog.3236.jpg',
#  'dog.6236.jpg',
#  'dog.12207.jpg',
#  'dog.5482.jpg',
#  'cat.10820.jpg',
#  'dog.8287.jpg',
#  'dog.6100.jpg',
#  'cat.8901.jpg',
#  'cat.8883.jpg',
#  'cat.9037.jpg',
#  'dog.3752.jpg',
#  'dog.20.jpg',
#  'cat.4862.jpg',
#  'dog.4789.jpg',
#  'cat.2945.jpg',
#  'dog.3478.jpg',
#  'cat.9657.jpg',
#  'dog.8627.jpg',
#  'dog.1581.jpg',
#  'cat.9115.jpg',
#  'dog.8599.jpg',
#  'cat.3518.jpg',
#  'cat.8621.jpg',
#  'dog.5891.jpg',
#  'cat.6761.jpg',
#  'dog.2301.jpg',
#  'cat.7276.jpg',
#  'cat.5437.jpg',
#  'dog.4114.jpg',
#  'dog.7309.jpg',
#  'dog.7332.jpg',
#  'dog.10524.jpg',
#  'dog.11990.jpg',
#  'dog.4545.jpg',
#  'dog.10884.jpg',
#  'cat.7722.jpg',
#  'cat.2929.jpg',
#  'cat.11509.jpg',
#  'dog.11822.jpg',
#  'dog.7138.jpg',
#  'dog.9539.jpg',
#  ...]

# %%
## 파일명에서 label 추출하기

## os.listdir(path)[0].split('.')

# %%
import random

full_names = os.listdir(path)
full_names = random.choices(full_names, k=10000)
full_names
# Out:
# ['dog.86.jpg',
#  'dog.12408.jpg',
#  'dog.621.jpg',
#  'dog.4974.jpg',
#  'cat.8407.jpg',
#  'dog.3876.jpg',
#  'cat.6693.jpg',
#  'dog.3211.jpg',
#  'cat.2415.jpg',
#  'dog.1490.jpg',
#  'cat.12345.jpg',
#  'dog.1443.jpg',
#  'cat.1364.jpg',
#  'cat.6982.jpg',
#  'dog.4840.jpg',
#  'cat.6524.jpg',
#  'dog.4954.jpg',
#  'cat.594.jpg',
#  'dog.9423.jpg',
#  'dog.9433.jpg',
#  'dog.9747.jpg',
#  'dog.4327.jpg',
#  'dog.7004.jpg',
#  'dog.11858.jpg',
#  'cat.5559.jpg',
#  'cat.4546.jpg',
#  'cat.1610.jpg',
#  'dog.9148.jpg',
#  'cat.4577.jpg',
#  'dog.6437.jpg',
#  'cat.8792.jpg',
#  'cat.2824.jpg',
#  'cat.11882.jpg',
#  'dog.2753.jpg',
#  'cat.552.jpg',
#  'dog.6.jpg',
#  'dog.9037.jpg',
#  'cat.292.jpg',
#  'dog.11572.jpg',
#  'cat.3795.jpg',
#  'dog.211.jpg',
#  'dog.859.jpg',
#  'dog.5431.jpg',
#  'cat.12348.jpg',
#  'cat.9626.jpg',
#  'cat.3190.jpg',
#  'cat.8363.jpg',
#  'dog.6814.jpg',
#  'cat.7270.jpg',
#  'cat.2687.jpg',
#  'dog.6106.jpg',
#  'dog.12149.jpg',
#  'cat.11220.jpg',
#  'cat.12259.jpg',
#  'dog.586.jpg',
#  'dog.4953.jpg',
#  'cat.6609.jpg',
#  'cat.9197.jpg',
#  'dog.6555.jpg',
#  'dog.6624.jpg',
#  'dog.6640.jpg',
#  'dog.8646.jpg',
#  'cat.5946.jpg',
#  'dog.4324.jpg',
#  'cat.10288.jpg',
#  'dog.3110.jpg',
#  'dog.1797.jpg',
#  'cat.9622.jpg',
#  'dog.5045.jpg',
#  'cat.4220.jpg',
#  'cat.794.jpg',
#  'cat.2266.jpg',
#  'cat.9774.jpg',
#  'cat.2673.jpg',
#  'cat.7569.jpg',
#  'cat.8094.jpg',
#  'dog.9782.jpg',
#  'dog.8090.jpg',
#  'dog.10195.jpg',
#  'cat.4.jpg',
#  'cat.10734.jpg',
#  'cat.1077.jpg',
#  'cat.236.jpg',
#  'cat.9311.jpg',
#  'dog.10398.jpg',
#  'cat.7003.jpg',
#  'dog.8255.jpg',
#  'cat.3545.jpg',
#  'cat.9604.jpg',
#  'dog.12158.jpg',
#  'dog.8485.jpg',
#  'dog.8213.jpg',
#  'dog.6510.jpg',
#  'dog.936.jpg',
#  'dog.8934.jpg',
#  'dog.9083.jpg',
#  'cat.5435.jpg',
#  'cat.2214.jpg',
#  'dog.8431.jpg',
#  'cat.11.jpg',
#  'dog.6138.jpg',
#  'dog.5597.jpg',
#  'dog.10659.jpg',
#  'dog.11566.jpg',
#  'cat.9937.jpg',
#  'dog.8279.jpg',
#  'dog.2091.jpg',
#  'cat.11090.jpg',
#  'dog.3445.jpg',
#  'dog.4769.jpg',
#  'cat.51.jpg',
#  'cat.11225.jpg',
#  'cat.1482.jpg',
#  'dog.548.jpg',
#  'dog.10780.jpg',
#  'dog.8589.jpg',
#  'cat.6598.jpg',
#  'dog.5582.jpg',
#  'dog.12457.jpg',
#  'cat.4456.jpg',
#  'cat.9511.jpg',
#  'cat.2061.jpg',
#  'dog.4148.jpg',
#  'dog.2876.jpg',
#  'cat.9060.jpg',
#  'dog.12019.jpg',
#  'cat.8927.jpg',
#  'dog.3998.jpg',
#  'dog.7412.jpg',
#  'dog.1492.jpg',
#  'dog.1841.jpg',
#  'cat.11941.jpg',
#  'dog.2690.jpg',
#  'cat.3949.jpg',
#  'cat.8995.jpg',
#  'cat.3694.jpg',
#  'dog.12061.jpg',
#  'cat.5101.jpg',
#  'dog.2399.jpg',
#  'dog.11072.jpg',
#  'dog.7322.jpg',
#  'dog.1312.jpg',
#  'dog.3884.jpg',
#  'cat.12224.jpg',
#  'cat.2891.jpg',
#  'dog.6363.jpg',
#  'cat.5595.jpg',
#  'cat.9273.jpg',
#  'cat.6940.jpg',
#  'dog.6483.jpg',
#  'dog.3731.jpg',
#  'dog.3629.jpg',
#  'cat.4491.jpg',
#  'cat.7671.jpg',
#  'cat.9702.jpg',
#  'cat.6667.jpg',
#  'dog.5920.jpg',
#  'cat.7003.jpg',
#  'dog.2361.jpg',
#  'cat.8626.jpg',
#  'cat.9563.jpg',
#  'dog.11508.jpg',
#  'dog.135.jpg',
#  'dog.10512.jpg',
#  'dog.659.jpg',
#  'cat.7007.jpg',
#  'dog.6715.jpg',
#  'cat.353.jpg',
#  'dog.10624.jpg',
#  'dog.6236.jpg',
#  'cat.414.jpg',
#  'cat.3662.jpg',
#  'dog.11588.jpg',
#  'cat.3245.jpg',
#  'cat.4830.jpg',
#  'dog.8266.jpg',
#  'cat.2213.jpg',
#  'dog.9522.jpg',
#  'cat.272.jpg',
#  'cat.10009.jpg',
#  'dog.10047.jpg',
#  'dog.3453.jpg',
#  'dog.2018.jpg',
#  'cat.4076.jpg',
#  'cat.3798.jpg',
#  'dog.2841.jpg',
#  'dog.3149.jpg',
#  'cat.3902.jpg',
#  'dog.11667.jpg',
#  'dog.5033.jpg',
#  'dog.6361.jpg',
#  'dog.11597.jpg',
#  'dog.31.jpg',
#  'cat.7537.jpg',
#  'dog.8585.jpg',
#  'dog.8739.jpg',
#  'cat.7201.jpg',
#  'cat.11139.jpg',
#  'dog.10136.jpg',
#  'cat.1442.jpg',
#  'dog.2657.jpg',
#  'dog.8001.jpg',
#  'cat.10259.jpg',
#  'cat.7007.jpg',
#  'dog.4865.jpg',
#  'cat.5437.jpg',
#  'dog.3520.jpg',
#  'dog.9219.jpg',
#  'cat.8826.jpg',
#  'dog.8597.jpg',
#  'cat.1633.jpg',
#  'dog.4696.jpg',
#  'dog.1216.jpg',
#  'cat.4701.jpg',
#  'dog.4104.jpg',
#  'cat.5892.jpg',
#  'dog.11953.jpg',
#  'cat.4081.jpg',
#  'dog.317.jpg',
#  'cat.4969.jpg',
#  'dog.6162.jpg',
#  'dog.5871.jpg',
#  'dog.12291.jpg',
#  'cat.2406.jpg',
#  'dog.10506.jpg',
#  'dog.4805.jpg',
#  'dog.3358.jpg',
#  'cat.6247.jpg',
#  'dog.9094.jpg',
#  'cat.10043.jpg',
#  'dog.9516.jpg',
#  'cat.2728.jpg',
#  'dog.12146.jpg',
#  'cat.5055.jpg',
#  'cat.1969.jpg',
#  'dog.10409.jpg',
#  'cat.2621.jpg',
#  'cat.6910.jpg',
#  'dog.10207.jpg',
#  'cat.258.jpg',
#  'dog.9754.jpg',
#  'cat.6665.jpg',
#  'cat.4491.jpg',
#  'cat.5890.jpg',
#  'cat.7406.jpg',
#  'dog.6281.jpg',
#  'dog.727.jpg',
#  'cat.9101.jpg',
#  'dog.7955.jpg',
#  'cat.1895.jpg',
#  'cat.10383.jpg',
#  'dog.11830.jpg',
#  'cat.9883.jpg',
#  'dog.5950.jpg',
#  'cat.2652.jpg',
#  'dog.10288.jpg',
#  'dog.8227.jpg',
#  'dog.12270.jpg',
#  'dog.10003.jpg',
#  'cat.5291.jpg',
#  'cat.8269.jpg',
#  'dog.7673.jpg',
#  'dog.7396.jpg',
#  'cat.526.jpg',
#  'dog.4345.jpg',
#  'dog.9110.jpg',
#  'cat.8262.jpg',
#  'cat.10983.jpg',
#  'cat.8720.jpg',
#  'cat.158.jpg',
#  'dog.11139.jpg',
#  'cat.8810.jpg',
#  'cat.3087.jpg',
#  'dog.1397.jpg',
#  'dog.5089.jpg',
#  'cat.5477.jpg',
#  'dog.11868.jpg',
#  'cat.10357.jpg',
#  'dog.5890.jpg',
#  'dog.336.jpg',
#  'cat.745.jpg',
#  'cat.777.jpg',
#  'dog.1245.jpg',
#  'cat.9082.jpg',
#  'dog.6621.jpg',
#  'dog.1795.jpg',
#  'cat.7893.jpg',
#  'dog.8752.jpg',
#  'dog.11698.jpg',
#  'cat.12263.jpg',
#  'cat.94.jpg',
#  'dog.5827.jpg',
#  'cat.10573.jpg',
#  'dog.5975.jpg',
#  'dog.2588.jpg',
#  'dog.1344.jpg',
#  'cat.9066.jpg',
#  'cat.159.jpg',
#  'dog.12354.jpg',
#  'cat.12029.jpg',
#  'cat.5969.jpg',
#  'dog.2635.jpg',
#  'dog.3023.jpg',
#  'cat.2243.jpg',
#  'dog.8772.jpg',
#  'dog.11388.jpg',
#  'dog.7432.jpg',
#  'dog.3891.jpg',
#  'cat.10109.jpg',
#  'dog.6521.jpg',
#  'dog.7329.jpg',
#  'cat.2486.jpg',
#  'dog.11219.jpg',
#  'cat.3802.jpg',
#  'dog.5639.jpg',
#  'dog.10667.jpg',
#  'dog.3511.jpg',
#  'cat.8985.jpg',
#  'dog.11587.jpg',
#  'cat.2319.jpg',
#  'dog.2367.jpg',
#  'dog.12103.jpg',
#  'dog.487.jpg',
#  'dog.570.jpg',
#  'dog.11142.jpg',
#  'cat.3374.jpg',
#  'cat.11597.jpg',
#  'cat.3474.jpg',
#  'dog.5758.jpg',
#  'dog.8533.jpg',
#  'dog.7202.jpg',
#  'cat.6186.jpg',
#  'cat.12257.jpg',
#  'cat.2857.jpg',
#  'cat.4554.jpg',
#  'cat.9816.jpg',
#  'cat.1283.jpg',
#  'cat.7733.jpg',
#  'dog.8567.jpg',
#  'cat.7426.jpg',
#  'cat.5959.jpg',
#  'dog.767.jpg',
#  'cat.11668.jpg',
#  'dog.11516.jpg',
#  'dog.11252.jpg',
#  'cat.10619.jpg',
#  'cat.858.jpg',
#  'cat.770.jpg',
#  'cat.12071.jpg',
#  'cat.8260.jpg',
#  'dog.10926.jpg',
#  'dog.8992.jpg',
#  'cat.691.jpg',
#  'cat.10733.jpg',
#  'dog.1373.jpg',
#  'dog.7631.jpg',
#  'cat.3049.jpg',
#  'dog.2834.jpg',
#  'cat.3218.jpg',
#  'cat.11941.jpg',
#  'cat.11542.jpg',
#  'dog.10707.jpg',
#  'cat.5821.jpg',
#  'dog.8979.jpg',
#  'dog.8354.jpg',
#  'dog.4457.jpg',
#  'dog.3688.jpg',
#  'cat.2235.jpg',
#  'dog.802.jpg',
#  'cat.1567.jpg',
#  'cat.4297.jpg',
#  'dog.3883.jpg',
#  'cat.12285.jpg',
#  'dog.3017.jpg',
#  'cat.6271.jpg',
#  'cat.9871.jpg',
#  'dog.3085.jpg',
#  'cat.546.jpg',
#  'dog.7247.jpg',
#  'dog.3035.jpg',
#  'dog.4040.jpg',
#  'dog.3013.jpg',
#  'dog.7686.jpg',
#  'dog.9495.jpg',
#  'cat.11709.jpg',
#  'dog.5720.jpg',
#  'dog.2034.jpg',
#  'dog.4788.jpg',
#  'dog.9492.jpg',
#  'cat.9393.jpg',
#  'cat.3651.jpg',
#  'dog.22.jpg',
#  'dog.7712.jpg',
#  'cat.10878.jpg',
#  'cat.5854.jpg',
#  'cat.1048.jpg',
#  'dog.361.jpg',
#  'dog.7046.jpg',
#  'dog.4751.jpg',
#  'dog.4962.jpg',
#  'cat.1309.jpg',
#  'cat.12166.jpg',
#  'cat.439.jpg',
#  'dog.12489.jpg',
#  'cat.10848.jpg',
#  'cat.10064.jpg',
#  'cat.12140.jpg',
#  'dog.2970.jpg',
#  'dog.9430.jpg',
#  'dog.9840.jpg',
#  'dog.11242.jpg',
#  'cat.8711.jpg',
#  'dog.1942.jpg',
#  'cat.2599.jpg',
#  'cat.9425.jpg',
#  'dog.3643.jpg',
#  'dog.8051.jpg',
#  'cat.1516.jpg',
#  'dog.8240.jpg',
#  'dog.5920.jpg',
#  'dog.10113.jpg',
#  'cat.1686.jpg',
#  'dog.1346.jpg',
#  'dog.3379.jpg',
#  'dog.286.jpg',
#  'dog.3996.jpg',
#  'cat.11733.jpg',
#  'dog.10920.jpg',
#  'dog.10575.jpg',
#  'cat.8245.jpg',
#  'dog.1418.jpg',
#  'dog.7221.jpg',
#  'dog.3518.jpg',
#  'dog.9339.jpg',
#  'dog.2932.jpg',
#  'dog.12080.jpg',
#  'cat.4875.jpg',
#  'cat.4347.jpg',
#  'dog.1175.jpg',
#  'cat.2776.jpg',
#  'cat.3014.jpg',
#  'dog.5949.jpg',
#  'cat.5983.jpg',
#  'cat.12490.jpg',
#  'dog.2222.jpg',
#  'dog.7935.jpg',
#  'dog.9306.jpg',
#  'cat.10275.jpg',
#  'dog.4921.jpg',
#  'cat.3553.jpg',
#  'cat.4307.jpg',
#  'cat.9531.jpg',
#  'cat.1588.jpg',
#  'dog.1137.jpg',
#  'cat.899.jpg',
#  'cat.904.jpg',
#  'cat.9656.jpg',
#  'dog.7397.jpg',
#  'dog.10420.jpg',
#  'cat.9133.jpg',
#  'cat.7863.jpg',
#  'cat.11324.jpg',
#  'cat.9873.jpg',
#  'dog.1318.jpg',
#  'cat.8817.jpg',
#  'dog.12336.jpg',
#  'cat.8562.jpg',
#  'dog.12387.jpg',
#  'cat.10003.jpg',
#  'cat.3471.jpg',
#  'cat.3664.jpg',
#  'dog.12182.jpg',
#  'dog.240.jpg',
#  'dog.1659.jpg',
#  'cat.5615.jpg',
#  'cat.12185.jpg',
#  'cat.5007.jpg',
#  'cat.11208.jpg',
#  'cat.25.jpg',
#  'cat.331.jpg',
#  'dog.10697.jpg',
#  'dog.11773.jpg',
#  'cat.7777.jpg',
#  'cat.5801.jpg',
#  'cat.10428.jpg',
#  'cat.2696.jpg',
#  'cat.576.jpg',
#  'dog.4367.jpg',
#  'cat.9098.jpg',
#  'dog.5665.jpg',
#  'dog.10003.jpg',
#  'cat.3192.jpg',
#  'dog.4662.jpg',
#  'cat.1574.jpg',
#  'dog.9329.jpg',
#  'cat.8346.jpg',
#  'dog.4684.jpg',
#  'cat.11290.jpg',
#  'cat.9612.jpg',
#  'cat.9531.jpg',
#  'cat.9880.jpg',
#  'dog.6287.jpg',
#  'cat.10660.jpg',
#  'dog.8256.jpg',
#  'cat.990.jpg',
#  'cat.11136.jpg',
#  'dog.491.jpg',
#  'dog.6989.jpg',
#  'cat.6588.jpg',
#  'cat.8410.jpg',
#  'cat.1381.jpg',
#  'dog.7572.jpg',
#  'dog.11538.jpg',
#  'dog.1213.jpg',
#  'dog.198.jpg',
#  'dog.2651.jpg',
#  'cat.9489.jpg',
#  'cat.1913.jpg',
#  'dog.11416.jpg',
#  'cat.5650.jpg',
#  'cat.10085.jpg',
#  'cat.6690.jpg',
#  'dog.1984.jpg',
#  'dog.4734.jpg',
#  'dog.9251.jpg',
#  'cat.11945.jpg',
#  'dog.5063.jpg',
#  'cat.3332.jpg',
#  'cat.3647.jpg',
#  'cat.7492.jpg',
#  'dog.4163.jpg',
#  'dog.1532.jpg',
#  'dog.9657.jpg',
#  'cat.7389.jpg',
#  'cat.375.jpg',
#  'dog.4427.jpg',
#  'dog.2070.jpg',
#  'dog.8370.jpg',
#  'dog.3897.jpg',
#  'dog.653.jpg',
#  'cat.7326.jpg',
#  'cat.190.jpg',
#  'dog.6942.jpg',
#  'dog.397.jpg',
#  'dog.2468.jpg',
#  'dog.4061.jpg',
#  'dog.4485.jpg',
#  'dog.3536.jpg',
#  'dog.10852.jpg',
#  'dog.3184.jpg',
#  'cat.12348.jpg',
#  'dog.278.jpg',
#  'dog.3458.jpg',
#  'dog.548.jpg',
#  'dog.3848.jpg',
#  'dog.9777.jpg',
#  'dog.5154.jpg',
#  'dog.2981.jpg',
#  'dog.938.jpg',
#  'dog.3279.jpg',
#  'dog.4345.jpg',
#  'cat.8291.jpg',
#  'dog.6416.jpg',
#  'cat.5822.jpg',
#  'dog.8696.jpg',
#  'dog.6923.jpg',
#  'dog.4118.jpg',
#  'dog.11014.jpg',
#  'cat.1700.jpg',
#  'dog.11193.jpg',
#  'cat.7911.jpg',
#  'dog.8959.jpg',
#  'dog.11809.jpg',
#  'cat.7300.jpg',
#  'dog.11237.jpg',
#  'dog.6516.jpg',
#  'dog.2134.jpg',
#  'cat.11759.jpg',
#  'dog.4740.jpg',
#  'cat.6803.jpg',
#  'cat.11150.jpg',
#  'cat.5948.jpg',
#  'dog.4577.jpg',
#  'dog.7685.jpg',
#  'dog.3722.jpg',
#  'dog.3470.jpg',
#  'dog.831.jpg',
#  'cat.3715.jpg',
#  'cat.5307.jpg',
#  'dog.4338.jpg',
#  'cat.8047.jpg',
#  'cat.10289.jpg',
#  'dog.7979.jpg',
#  'dog.6525.jpg',
#  'dog.7196.jpg',
#  'dog.1888.jpg',
#  'dog.11156.jpg',
#  'cat.10476.jpg',
#  'cat.961.jpg',
#  'cat.8442.jpg',
#  'dog.8569.jpg',
#  'cat.7765.jpg',
#  'dog.8623.jpg',
#  'dog.4692.jpg',
#  'cat.7105.jpg',
#  'cat.3954.jpg',
#  'dog.7827.jpg',
#  'dog.11241.jpg',
#  'cat.8284.jpg',
#  'dog.3057.jpg',
#  'dog.9613.jpg',
#  'cat.446.jpg',
#  'cat.8893.jpg',
#  'cat.9949.jpg',
#  'cat.219.jpg',
#  'cat.2911.jpg',
#  'dog.2618.jpg',
#  'dog.7.jpg',
#  'dog.6850.jpg',
#  'cat.7925.jpg',
#  'cat.10357.jpg',
#  'cat.6237.jpg',
#  'cat.9086.jpg',
#  'dog.2879.jpg',
#  'cat.2350.jpg',
#  'dog.3638.jpg',
#  'cat.4936.jpg',
#  'cat.1294.jpg',
#  'cat.5753.jpg',
#  'cat.1921.jpg',
#  'cat.11862.jpg',
#  'dog.2976.jpg',
#  'cat.9358.jpg',
#  'dog.3316.jpg',
#  'cat.7388.jpg',
#  'cat.4336.jpg',
#  'dog.10899.jpg',
#  'dog.11280.jpg',
#  'dog.1083.jpg',
#  'dog.8547.jpg',
#  'cat.11096.jpg',
#  'cat.6947.jpg',
#  'cat.8026.jpg',
#  'cat.1405.jpg',
#  'dog.1674.jpg',
#  'cat.1022.jpg',
#  'cat.1184.jpg',
#  'cat.1165.jpg',
#  'dog.11769.jpg',
#  'cat.11981.jpg',
#  'cat.9106.jpg',
#  'cat.5831.jpg',
#  'dog.10024.jpg',
#  'cat.7926.jpg',
#  'cat.6185.jpg',
#  'dog.1183.jpg',
#  'dog.5727.jpg',
#  'cat.600.jpg',
#  'cat.325.jpg',
#  'cat.8609.jpg',
#  'dog.11897.jpg',
#  'cat.3876.jpg',
#  'cat.11657.jpg',
#  'dog.3934.jpg',
#  'cat.1764.jpg',
#  'cat.8482.jpg',
#  'dog.2171.jpg',
#  'cat.4816.jpg',
#  'cat.7763.jpg',
#  'dog.11877.jpg',
#  'cat.10023.jpg',
#  'dog.2339.jpg',
#  'cat.404.jpg',
#  'cat.4371.jpg',
#  'cat.5995.jpg',
#  'cat.7220.jpg',
#  'cat.2478.jpg',
#  'dog.10516.jpg',
#  'cat.10735.jpg',
#  'dog.10421.jpg',
#  'cat.8369.jpg',
#  'dog.12437.jpg',
#  'dog.6315.jpg',
#  'cat.1197.jpg',
#  'dog.406.jpg',
#  'cat.4685.jpg',
#  'dog.10748.jpg',
#  'cat.54.jpg',
#  'dog.11964.jpg',
#  'cat.2973.jpg',
#  'cat.11556.jpg',
#  'dog.5622.jpg',
#  'dog.8739.jpg',
#  'cat.9880.jpg',
#  'cat.10381.jpg',
#  'dog.296.jpg',
#  'dog.4646.jpg',
#  'cat.2422.jpg',
#  'dog.256.jpg',
#  'dog.2139.jpg',
#  'cat.9100.jpg',
#  'cat.4708.jpg',
#  'dog.11042.jpg',
#  'cat.4657.jpg',
#  'cat.1019.jpg',
#  'cat.7347.jpg',
#  'cat.10044.jpg',
#  'dog.521.jpg',
#  'dog.5215.jpg',
#  'cat.5403.jpg',
#  'dog.7340.jpg',
#  'dog.4677.jpg',
#  'cat.6802.jpg',
#  'dog.6557.jpg',
#  'cat.147.jpg',
#  'cat.3753.jpg',
#  'dog.4423.jpg',
#  'cat.963.jpg',
#  'dog.10721.jpg',
#  'dog.3709.jpg',
#  'cat.9232.jpg',
#  'dog.6751.jpg',
#  'cat.10533.jpg',
#  'cat.10720.jpg',
#  'dog.10871.jpg',
#  'dog.6374.jpg',
#  'dog.3143.jpg',
#  'dog.8808.jpg',
#  'cat.9231.jpg',
#  'dog.6939.jpg',
#  'cat.8391.jpg',
#  'dog.4112.jpg',
#  'dog.9851.jpg',
#  'cat.4095.jpg',
#  'dog.7354.jpg',
#  'dog.6957.jpg',
#  'cat.4933.jpg',
#  'dog.7896.jpg',
#  'cat.5414.jpg',
#  'cat.11692.jpg',
#  'cat.5292.jpg',
#  'cat.7464.jpg',
#  'cat.7253.jpg',
#  'cat.2407.jpg',
#  'cat.8047.jpg',
#  'dog.2181.jpg',
#  'cat.4130.jpg',
#  'dog.5203.jpg',
#  'dog.9846.jpg',
#  'cat.6564.jpg',
#  'cat.11881.jpg',
#  'cat.4725.jpg',
#  'cat.4768.jpg',
#  'cat.2382.jpg',
#  'cat.9258.jpg',
#  'dog.3525.jpg',
#  'cat.10904.jpg',
#  'cat.10637.jpg',
#  'cat.44.jpg',
#  'dog.4077.jpg',
#  'dog.1259.jpg',
#  'dog.10813.jpg',
#  'cat.6867.jpg',
#  'cat.12118.jpg',
#  'dog.4878.jpg',
#  'dog.3589.jpg',
#  'dog.7924.jpg',
#  'dog.10015.jpg',
#  'cat.832.jpg',
#  'cat.7362.jpg',
#  'cat.4700.jpg',
#  'dog.11301.jpg',
#  'cat.5928.jpg',
#  'cat.6623.jpg',
#  'dog.3160.jpg',
#  'cat.11319.jpg',
#  'dog.11582.jpg',
#  'dog.10540.jpg',
#  'cat.972.jpg',
#  'dog.2488.jpg',
#  'cat.8468.jpg',
#  'dog.4008.jpg',
#  'cat.7024.jpg',
#  'dog.5013.jpg',
#  'cat.11068.jpg',
#  'cat.4581.jpg',
#  'dog.9459.jpg',
#  'cat.6342.jpg',
#  'dog.8348.jpg',
#  'dog.6108.jpg',
#  'dog.11625.jpg',
#  'cat.1883.jpg',
#  'cat.3682.jpg',
#  'dog.519.jpg',
#  'dog.1367.jpg',
#  'cat.11507.jpg',
#  'dog.3750.jpg',
#  'cat.10951.jpg',
#  'dog.9861.jpg',
#  'cat.6410.jpg',
#  'cat.3011.jpg',
#  'cat.5976.jpg',
#  'dog.1242.jpg',
#  'dog.6910.jpg',
#  'dog.2233.jpg',
#  'cat.4244.jpg',
#  'cat.9948.jpg',
#  'dog.7109.jpg',
#  'dog.2598.jpg',
#  'cat.1915.jpg',
#  'dog.12283.jpg',
#  'dog.6460.jpg',
#  'dog.10800.jpg',
#  'cat.4685.jpg',
#  'cat.10624.jpg',
#  'dog.10971.jpg',
#  'dog.2720.jpg',
#  'cat.9016.jpg',
#  'dog.10563.jpg',
#  'cat.3771.jpg',
#  'cat.6899.jpg',
#  'cat.3466.jpg',
#  'cat.106.jpg',
#  'dog.5424.jpg',
#  'cat.7029.jpg',
#  'dog.189.jpg',
#  'cat.9623.jpg',
#  'dog.399.jpg',
#  'dog.2740.jpg',
#  'cat.1762.jpg',
#  'cat.12132.jpg',
#  'dog.5482.jpg',
#  'cat.11983.jpg',
#  'dog.2832.jpg',
#  'dog.2485.jpg',
#  'cat.5011.jpg',
#  'cat.10849.jpg',
#  'dog.9390.jpg',
#  'dog.8041.jpg',
#  'dog.10537.jpg',
#  'dog.2039.jpg',
#  'dog.4889.jpg',
#  'dog.10036.jpg',
#  'cat.8306.jpg',
#  'cat.11530.jpg',
#  'dog.5880.jpg',
#  'dog.10673.jpg',
#  'dog.5754.jpg',
#  'dog.4314.jpg',
#  'dog.170.jpg',
#  'dog.3278.jpg',
#  'dog.6808.jpg',
#  'cat.5610.jpg',
#  'dog.2816.jpg',
#  'dog.1180.jpg',
#  'dog.8236.jpg',
#  'cat.8707.jpg',
#  'dog.5822.jpg',
#  'cat.6742.jpg',
#  'dog.3937.jpg',
#  'dog.4677.jpg',
#  'dog.5048.jpg',
#  'cat.769.jpg',
#  'dog.5803.jpg',
#  'cat.6795.jpg',
#  'cat.5989.jpg',
#  'cat.8231.jpg',
#  'cat.5532.jpg',
#  'dog.11305.jpg',
#  'cat.1095.jpg',
#  'cat.8110.jpg',
#  'cat.8682.jpg',
#  'cat.4116.jpg',
#  'cat.3571.jpg',
#  'cat.500.jpg',
#  'dog.3512.jpg',
#  'dog.7498.jpg',
#  'cat.7613.jpg',
#  'cat.4104.jpg',
#  'cat.2344.jpg',
#  'dog.708.jpg',
#  'dog.8582.jpg',
#  'cat.4219.jpg',
#  'cat.958.jpg',
#  'dog.4097.jpg',
#  'cat.105.jpg',
#  'cat.12065.jpg',
#  'dog.6297.jpg',
#  'cat.2388.jpg',
#  'cat.11691.jpg',
#  'dog.947.jpg',
#  'cat.8268.jpg',
#  'cat.6797.jpg',
#  'cat.11264.jpg',
#  'cat.11523.jpg',
#  'cat.1055.jpg',
#  'dog.8150.jpg',
#  'dog.2559.jpg',
#  'cat.464.jpg',
#  'dog.3611.jpg',
#  'cat.4328.jpg',
#  'cat.6022.jpg',
#  'dog.11238.jpg',
#  'dog.2070.jpg',
#  'cat.1816.jpg',
#  'dog.442.jpg',
#  'dog.8670.jpg',
#  'cat.3300.jpg',
#  'dog.5304.jpg',
#  'cat.9447.jpg',
#  'dog.5451.jpg',
#  'dog.1574.jpg',
#  'dog.1459.jpg',
#  'cat.9391.jpg',
#  'dog.10319.jpg',
#  'cat.447.jpg',
#  'cat.1609.jpg',
#  'cat.7811.jpg',
#  'cat.3383.jpg',
#  'dog.2151.jpg',
#  'dog.10054.jpg',
#  'dog.10874.jpg',
#  'cat.5491.jpg',
#  'cat.11353.jpg',
#  'cat.6343.jpg',
#  'cat.631.jpg',
#  'cat.10720.jpg',
#  'cat.8111.jpg',
#  'cat.5145.jpg',
#  'cat.1029.jpg',
#  'cat.2211.jpg',
#  'dog.10998.jpg',
#  'dog.5331.jpg',
#  'cat.11727.jpg',
#  'dog.11670.jpg',
#  'dog.2809.jpg',
#  'cat.1218.jpg',
#  'dog.10267.jpg',
#  'dog.9597.jpg',
#  'cat.6238.jpg',
#  'dog.1247.jpg',
#  'cat.3179.jpg',
#  'cat.10922.jpg',
#  'dog.3654.jpg',
#  'cat.3421.jpg',
#  'cat.12483.jpg',
#  'dog.8891.jpg',
#  'cat.10865.jpg',
#  'dog.7173.jpg',
#  'cat.9624.jpg',
#  'dog.10859.jpg',
#  'dog.8465.jpg',
#  'dog.170.jpg',
#  'dog.8395.jpg',
#  'cat.8667.jpg',
#  'dog.612.jpg',
#  'dog.10010.jpg',
#  'cat.6299.jpg',
#  'dog.4336.jpg',
#  'dog.3141.jpg',
#  'dog.8225.jpg',
#  'cat.10951.jpg',
#  'dog.11830.jpg',
#  'cat.11166.jpg',
#  'dog.5569.jpg',
#  'cat.5904.jpg',
#  'cat.84.jpg',
#  'dog.325.jpg',
#  'cat.5595.jpg',
#  'dog.2940.jpg',
#  'cat.6504.jpg',
#  'dog.8123.jpg',
#  'dog.11290.jpg',
#  'cat.4417.jpg',
#  'cat.3966.jpg',
#  'dog.473.jpg',
#  'cat.618.jpg',
#  'dog.7652.jpg',
#  'cat.5353.jpg',
#  'cat.2556.jpg',
#  'cat.739.jpg',
#  'dog.4480.jpg',
#  'dog.4189.jpg',
#  'dog.9610.jpg',
#  'dog.2165.jpg',
#  'dog.8443.jpg',
#  'cat.5529.jpg',
#  'dog.997.jpg',
#  'dog.8438.jpg',
#  'dog.6049.jpg',
#  'cat.8591.jpg',
#  'cat.6919.jpg',
#  'dog.2087.jpg',
#  'dog.24.jpg',
#  'dog.10921.jpg',
#  'cat.4569.jpg',
#  'dog.9426.jpg',
#  'dog.7029.jpg',
#  'dog.8619.jpg',
#  'cat.1219.jpg',
#  ...]

# %%
# full_names = os.listdir(path)
labels = [each.split('.')[0] for each in full_names]
file_id = [each.split('.')[1] for each in full_names]

# %%
import random 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

sample = random.choice(full_names)
image = mpimg.imread(path + sample)
plt.imshow(image)
plt.show()

# %%
## 제각각인 사진 크기 조정

sample = random.choice(full_names)
image = mpimg.imread(path + sample)
image.shape
# Out:
# (331, 500, 3)

# %%
## 크기를 하나로 고정

from skimage.transform import resize
resized = resize(image, (128, 128, 3))

fig, axes = plt.subplots(1,2, figsize=(8, 4))
ax = axes.ravel()

ax[0].imshow(image, cmap=plt.cm.gray)
ax[0].set_title("image")
ax[1].imshow(resized, cmap=plt.cm.gray)
ax[1].set_title("Resized")

fig.tight_layout()
plt.show()

# %%
## 크기를 바꿔서 읽어보자

from tqdm.notebook import tqdm
from skimage.color import rgb2gray
import numpy as np

images = []
bar_total = tqdm(full_names)
for file in bar_total :
    image = mpimg.imread(path + file)
    images.append(resize(image, (128, 128, 3)))
    
images = np.array(images)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
images.shape, labels[:3]
# Out:
# ((10000, 128, 128, 3), ['dog', 'dog', 'dog'])

# %%
images[:3]
# Out:
# array([[[[2.77113971e-02, 5.90720981e-02, 6.50323606e-04],
#          [4.63155709e-02, 7.54258698e-02, 1.72279508e-02],
#          [1.00800638e-01, 1.14801863e-01, 6.07424269e-02],
#          ...,
#          [4.95139328e-02, 3.39359059e-02, 3.00633449e-02],
#          [5.92420391e-02, 4.35735366e-02, 3.96697400e-02],
#          [7.97299853e-02, 6.40437107e-02, 6.01221421e-02]],
#
#         [[1.63602941e-02, 4.70177744e-02, 0.00000000e+00],
#          [3.66942761e-02, 5.95729454e-02, 4.25738166e-03],
#          [9.91727343e-02, 1.13085100e-01, 5.86120605e-02],
#          ...,
#          [2.91541604e-02, 1.63110471e-02, 1.26315248e-02],
#          [2.52144608e-02, 1.03406719e-02, 5.32352223e-03],
#          [3.66930195e-02, 2.10245170e-02, 1.62401985e-02]],
#
#         [[1.84579288e-02, 4.58200492e-02, 2.96200023e-05],
#          [4.22457826e-02, 6.62010642e-02, 7.46639476e-03],
#          [1.18652822e-01, 1.30729047e-01, 7.32892803e-02],
#          ...,
#          [6.88622568e-02, 5.45597450e-02, 3.87969372e-02],
#          [8.01409553e-02, 6.79595947e-02, 4.78063845e-02],
#          [8.40676102e-02, 6.92095588e-02, 5.44097302e-02]],
#
#         ...,
#
#         [[1.28640687e-01, 1.04069609e-01, 4.09719430e-03],
#          [1.21182550e-01, 1.05306349e-01, 5.31550389e-03],
#          [1.14716234e-01, 1.08410046e-01, 1.94394579e-02],
#          ...,
#          [1.61698225e-01, 1.42090382e-01, 2.83648921e-02],
#          [1.71577843e-01, 1.51969999e-01, 3.82445092e-02],
#          [1.95786360e-01, 1.68672390e-01, 5.86999631e-02]],
#
#         [[1.16021429e-01, 9.61862601e-02, 4.69970703e-04],
#          [1.39920942e-01, 1.25245696e-01, 1.43694709e-02],
#          [1.37163050e-01, 1.31004962e-01, 3.29504275e-02],
#          ...,
#          [1.43388516e-01, 1.23780673e-01, 1.00551830e-02],
#          [1.55989583e-01, 1.36381740e-01, 2.26562500e-02],
#          [1.87750005e-01, 1.60636034e-01, 5.06636077e-02]],
#
#         [[1.33986110e-01, 1.14709353e-01, 1.31841921e-03],
#          [1.60969992e-01, 1.50078448e-01, 3.03198721e-02],
#          [1.35416667e-01, 1.32229375e-01, 2.44352453e-02],
#          ...,
#          [1.55538163e-01, 1.35930319e-01, 2.22048292e-02],
#          [1.75086407e-01, 1.55478563e-01, 4.17530733e-02],
#          [1.58893780e-01, 1.31779809e-01, 2.18073826e-02]]],
#
#
#        [[[5.64949624e-01, 8.19554776e-01, 7.41271808e-01],
#          [6.06644633e-01, 8.48325212e-01, 7.76499641e-01],
#          [6.22904798e-01, 8.50837131e-01, 7.78728748e-01],
#          ...,
#          [4.88692494e-01, 6.84770925e-01, 5.86731709e-01],
#          [4.51213125e-01, 6.47291557e-01, 5.49252341e-01],
#          [4.49887969e-01, 6.45966400e-01, 5.47927185e-01]],
#
#         [[5.72972650e-01, 8.23429548e-01, 7.47220707e-01],
#          [6.00416430e-01, 8.40948732e-01, 7.69697299e-01],
#          [6.41515173e-01, 8.66818883e-01, 7.94710499e-01],
#          ...,
#          [5.02423323e-01, 6.98501755e-01, 5.97337539e-01],
#          [4.67533468e-01, 6.63611899e-01, 5.62447683e-01],
#          [4.55887198e-01, 6.51965629e-01, 5.50801413e-01]],
#
#         [[5.88501651e-01, 8.35555051e-01, 7.61046876e-01],
#          [5.93947498e-01, 8.30150299e-01, 7.58902707e-01],
#          [6.40917138e-01, 8.63025424e-01, 7.92512359e-01],
#          ...,
#          [5.23813642e-01, 7.19892073e-01, 6.14009720e-01],
#          [4.88417484e-01, 6.84495915e-01, 5.78613563e-01],
#          [4.65668479e-01, 6.61746910e-01, 5.55864557e-01]],
#
#         ...,
#
#         [[6.20088866e-01, 7.86973552e-01, 5.29318855e-01],
#          [6.02634761e-01, 7.71927413e-01, 5.02878556e-01],
#          [5.48349730e-01, 7.24784792e-01, 4.44361923e-01],
#          ...,
#          [7.81429727e-01, 8.79468943e-01, 6.19031327e-01],
#          [8.38290163e-01, 9.36329379e-01, 6.77058041e-01],
#          [8.08433267e-01, 9.06472483e-01, 6.46914691e-01]],
#
#         [[5.33224448e-01, 7.03307518e-01, 4.52495275e-01],
#          [5.57557250e-01, 7.30629415e-01, 4.70274388e-01],
#          [6.10585338e-01, 7.76864307e-01, 5.15027584e-01],
#          ...,
#          [7.64175041e-01, 8.63659428e-01, 5.93867867e-01],
#          [7.87967250e-01, 8.86407411e-01, 6.21131788e-01],
#          [7.97559895e-01, 8.96256532e-01, 6.29871731e-01]],
#
#         [[5.84964506e-01, 7.64457531e-01, 5.13708663e-01],
#          [5.90330071e-01, 7.64547048e-01, 5.15872868e-01],
#          [6.60510652e-01, 8.26756583e-01, 5.78766444e-01],
#          ...,
#          [7.57240221e-01, 8.58999235e-01, 5.81173172e-01],
#          [7.46948056e-01, 8.48476527e-01, 5.71342094e-01],
#          [8.09288272e-01, 9.10873368e-01, 6.33569060e-01]]],
#
#
#        [[[5.00865708e-01, 3.71453944e-01, 2.02826493e-01],
#          [5.00021793e-01, 3.70610028e-01, 2.01982577e-01],
#          [5.01566844e-01, 3.72155079e-01, 2.03527628e-01],
#          ...,
#          [5.24239349e-01, 4.59724462e-01, 4.28001345e-01],
#          [5.90632532e-01, 5.95929985e-01, 5.76212805e-01],
#          [6.07951963e-01, 5.79403227e-01, 5.60913373e-01]],
#
#         [[5.14725118e-01, 3.85313353e-01, 2.16685902e-01],
#          [5.12011380e-01, 3.82599615e-01, 2.13972164e-01],
#          [5.10024063e-01, 3.80612298e-01, 2.11984847e-01],
#          ...,
#          [6.13714123e-01, 5.55906926e-01, 5.22637445e-01],
#          [6.47981920e-01, 6.36320976e-01, 6.06545404e-01],
#          [5.88113709e-01, 5.52936519e-01, 5.16080597e-01]],
#
#         [[5.14704584e-01, 3.85292820e-01, 2.16665369e-01],
#          [5.13866209e-01, 3.84454444e-01, 2.15826993e-01],
#          [5.17761773e-01, 3.88350009e-01, 2.19722558e-01],
#          ...,
#          [5.84900841e-01, 5.40726545e-01, 5.06743066e-01],
#          [5.71622163e-01, 5.42336322e-01, 5.01323876e-01],
#          [5.54312563e-01, 5.11557062e-01, 4.54221654e-01]],
#
#         ...,
#
#         [[2.09850251e-01, 1.94163977e-01, 1.51026722e-01],
#          [2.16912365e-01, 2.01226091e-01, 1.58088836e-01],
#          [2.28037129e-01, 2.12350855e-01, 1.69213549e-01],
#          ...,
#          [1.81091857e-01, 1.88935295e-01, 1.77170895e-01],
#          [1.88169552e-01, 1.97264761e-01, 1.86648938e-01],
#          [1.53455142e-01, 1.81897552e-01, 1.86064593e-01]],
#
#         [[2.20579638e-01, 2.04893363e-01, 1.61756108e-01],
#          [2.11697822e-01, 1.96011547e-01, 1.52874292e-01],
#          [2.35227850e-01, 2.19541575e-01, 1.76404270e-01],
#          ...,
#          [1.82495877e-01, 1.90339488e-01, 1.78575286e-01],
#          [1.79310807e-01, 1.89092603e-01, 1.79353730e-01],
#          [1.62625199e-01, 2.02189036e-01, 2.23555357e-01]],
#
#         [[2.20453182e-01, 2.04766907e-01, 1.61629652e-01],
#          [2.20859429e-01, 2.05173154e-01, 1.62035899e-01],
#          [2.41796088e-01, 2.26109814e-01, 1.82972509e-01],
#          ...,
#          [1.86948061e-01, 1.94791693e-01, 1.83027815e-01],
#          [1.72580217e-01, 1.82750033e-01, 1.74033362e-01],
#          [1.96488433e-01, 2.47096834e-01, 2.81229175e-01]]]])

# %%
## Label 인코딩 

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(labels)
labels_encoded = encoder.transform(labels)
labels_encoded[:3], encoder.classes_
# Out:
# (array([1, 1, 1]), array(['cat', 'dog'], dtype='<U3'))

# %%
# 데이터 나누고

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = \
        train_test_split(images, labels_encoded, test_size=0.2, 
                        random_state=13, stratify=labels_encoded)

X_train.shape, X_test.shape
# Out:
# ((8000, 128, 128, 3), (2000, 128, 128, 3))

# %%
samples = random.choices(population=range(0, 2000), k=8)

plt.figure(figsize=(14, 12))
for idx, n in enumerate(samples):
    plt.subplot(2, 4, idx+1)
    plt.imshow(X_train[n], cmap='Greys',
              interpolation='nearest')
    plt.title(y_train[n])
    
plt.tight_layout()
plt.show()

# %%
## 모델을 만들고!!

from tensorflow.keras import layers, models
# Out:
# 2022-11-28 15:04:34.446272: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-28 15:04:34.655065: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-28 15:04:35.605284: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.3/lib64
# 2022-11-28 15:04:35.605348: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.3/lib64
# 2022-11-28 15:04:35.605352: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    layers.MaxPooling2D(pool_size = (2, 2), strides = (2, 2)),
    layers.Dropout(0.25),
    
    layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'),
    layers.MaxPooling2D(pool_size = (2, 2)),
    layers.Dropout(0.25),
    
    layers.Conv2D(64, (3, 3), activation='relu', padding = 'same'),
    layers.MaxPooling2D(pool_size = (2, 2)),
    layers.Dropout(0.25),
    
    layers.Flatten(),
    layers.Dense(512, activation = 'relu'),
    layers.Dropout(0.25),
    layers.Dense(2, activation='softmax')
])
# Out:
# 2022-11-28 15:04:36.622677: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:36.650457: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:36.650774: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:36.651578: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-28 15:04:36.652197: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:36.652516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:36.652806: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:37.226805: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:37.227629: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:37.227966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-28 15:04:37.228285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4064 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 63, 63, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 31, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 31, 31, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 31, 31, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 15, 15, 64)        0
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 512)               7373312
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 7,430,658
# Trainable params: 7,430,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 컴파일 하고 학습

model.compile(optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
import time

start_time = time.time()
hist = model.fit(X_train.reshape(8000, 128, 128, 3), y_train,
                 epochs=5, verbose=1,
                 validation_data = (X_test.reshape(2000, 128, 128, 3), y_test))
print('fit time :', time.time() - start_time)
# Out:
# Epoch 1/5
# 2022-11-28 15:04:40.531302: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2022-11-28 15:04:41.315519: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2022-11-28 15:04:43.871553: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-11-28 15:04:43.887057: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fcaa07cddb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-11-28 15:04:43.887075: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2022-11-28 15:04:43.901383: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2022-11-28 15:04:44.062641: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 [==============================] - 11s 20ms/step - loss: 0.7402 - accuracy: 0.5263 - val_loss: 0.6699 - val_accuracy: 0.5845
# Epoch 2/5
# 250/250 [==============================] - 4s 18ms/step - loss: 0.6681 - accuracy: 0.5861 - val_loss: 0.6649 - val_accuracy: 0.6295
# Epoch 3/5
# 250/250 [==============================] - 4s 18ms/step - loss: 0.6344 - accuracy: 0.6379 - val_loss: 0.6197 - val_accuracy: 0.6720
# Epoch 4/5
# 250/250 [==============================] - 5s 18ms/step - loss: 0.5812 - accuracy: 0.6954 - val_loss: 0.5784 - val_accuracy: 0.7100
# Epoch 5/5
# 250/250 [==============================] - 4s 18ms/step - loss: 0.5145 - accuracy: 0.7474 - val_loss: 0.5221 - val_accuracy: 0.7450
# fit time : 31.303008794784546

# %%
plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']
plt.figure(figsize=(12, 8))

for each in plot_target:
    plt.plot(hist.history[each], label=each)
    
plt.legend()
plt.grid()
plt.show()
